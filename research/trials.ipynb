# %%
import os

# %%
import yaml

yaml_file_path = "test.yaml"

with open(yaml_file_path,"r") as file:
    data=yaml.safe_load(file)

# %%
data
# Out:
# {'key': 'value1', 'key2': 'value2'}

# %%
from box import ConfigBox

# %%
data = ConfigBox(data)

# %%
data
# Out:
# ConfigBox({'key': 'value1', 'key2': 'value2'})

# %%
data.key
# Out:
# 'value1'

# %%
data.key2
# Out:
# 'value2'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_data(x: int , y: int):
    return x*y

# %%
get_data(2,3)
# Out:
# 6

# %%
get_data(2,"6")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_data(2,"6")
#
# File c:\Users\kalla\.conda\envs\winequality\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_data at 0x00000142D9E33F70> does not match annotation type <class 'int'>
